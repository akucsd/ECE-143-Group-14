# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
dataset = pd.read_csv('C:\\Users\\Chris\\OneDrive\\Documents\\ECE 143\\project\\ObesityDataSet_raw_and_data_sinthetic.csv')
dataset
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
# dataset['BMI'] = dataset['Weight']/(dataset['Height']**2)
# dataset.columns
# data = dataset.copy()
# coles = ['Gender', 'Age', 'Height','Weight','BMI','family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC','SMOKE','CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad']
# data = data[coles]
# print(data.head())
# lEncoder = LabelEncoder()
# to_encode = [0,5,6,9,10,12,15,16,17]
# encoded = data.iloc[:, to_encode].apply(lambda col: lEncoder.fit_transform(col))
# # Assign the transformed values back to the original DataFrame
# data.iloc[:, to_encode] = encoded
# #Normalize the data

# scaler = MinMaxScaler(feature_range=(0, 1))
# normalized = scaler.fit_transform(data)
# normalized = pd.DataFrame(normalized, columns=coles)
# plt.figure(figsize=(15,10))
# sns.heatmap(normalized.corr(), annot = True)

# %%
dataset = dataset[['Gender', 'Age', 'Height','family_history_with_overweight',
       'FAVC', 'FCVC', 'NCP', 'CAEC', 'CH2O', 'SCC', 'FAF', 'TUE',
       'CALC', 'MTRANS', 'NObeyesdad']]
dataset = dataset.rename(columns={'family_history_with_overweight':'familyhistory'})
#Check if thed new column was calculated and placed correctly
dataset.head()
# Out:
#    Gender   Age  Height familyhistory FAVC  FCVC  NCP       CAEC  CH2O  SCC  \
# 0  Female  21.0    1.62           yes   no   2.0  3.0  Sometimes   2.0   no
# 1  Female  21.0    1.52           yes   no   3.0  3.0  Sometimes   3.0  yes
# 2    Male  23.0    1.80           yes   no   2.0  3.0  Sometimes   2.0   no
# 3    Male  27.0    1.80            no   no   3.0  3.0  Sometimes   2.0   no
# 4    Male  22.0    1.78            no   no   2.0  1.0  Sometimes   2.0   no
#
#    FAF  TUE        CALC                 MTRANS           NObeyesdad
# 0  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II

# %%
dataset1 = dataset.dropna()

# %%
dataset1
# Out:
#       Gender        Age    Height family_history_with_overweight FAVC  FCVC  \
# 0     Female  21.000000  1.620000                            yes   no   2.0
# 1     Female  21.000000  1.520000                            yes   no   3.0
# 2       Male  23.000000  1.800000                            yes   no   2.0
# 3       Male  27.000000  1.800000                             no   no   3.0
# 4       Male  22.000000  1.780000                             no   no   2.0
# ...      ...        ...       ...                            ...  ...   ...
# 2106  Female  20.976842  1.710730                            yes  yes   3.0
# 2107  Female  21.982942  1.748584                            yes  yes   3.0
# 2108  Female  22.524036  1.752206                            yes  yes   3.0
# 2109  Female  24.361936  1.739450                            yes  yes   3.0
# 2110  Female  23.664709  1.738836                            yes  yes   3.0
#
#       NCP       CAEC      CH2O  SCC       FAF       TUE        CALC  \
# 0     3.0  Sometimes  2.000000   no  0.000000  1.000000          no
# 1     3.0  Sometimes  3.000000  yes  3.000000  0.000000   Sometimes
# 2     3.0  Sometimes  2.000000   no  2.000000  1.000000  Frequently
# 3     3.0  Sometimes  2.000000   no  2.000000  0.000000  Frequently
# 4     1.0  Sometimes  2.000000   no  0.000000  0.000000   Sometimes
# ...   ...        ...       ...  ...       ...       ...         ...
# 2106  3.0  Sometimes  1.728139   no  1.676269  0.906247   Sometimes
# 2107  3.0  Sometimes  2.005130   no  1.341390  0.599270   Sometimes
# 2108  3.0  Sometimes  2.054193   no  1.414209  0.646288   Sometimes
# 2109  3.0  Sometimes  2.852339   no  1.139107  0.586035   Sometimes
# 2110  3.0  Sometimes  2.863513   no  1.026452  0.714137   Sometimes
#
#                      MTRANS           NObeyesdad
# 0     Public_Transportation        Normal_Weight
# 1     Public_Transportation        Normal_Weight
# 2     Public_Transportation        Normal_Weight
# 3                   Walking   Overweight_Level_I
# 4     Public_Transportation  Overweight_Level_II
# ...                     ...                  ...
# 2106  Public_Transportation     Obesity_Type_III
# 2107  Public_Transportation     Obesity_Type_III
# 2108  Public_Transportation     Obesity_Type_III
# 2109  Public_Transportation     Obesity_Type_III
# 2110  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 15 columns]

# %%
X = dataset.iloc[:,:14]
Y = dataset.iloc[:,[14]]

# %%
X
# Out:
#       Gender        Age    Height familyhistory FAVC  FCVC  NCP       CAEC  \
# 0     Female  21.000000  1.620000           yes   no   2.0  3.0  Sometimes
# 1     Female  21.000000  1.520000           yes   no   3.0  3.0  Sometimes
# 2       Male  23.000000  1.800000           yes   no   2.0  3.0  Sometimes
# 3       Male  27.000000  1.800000            no   no   3.0  3.0  Sometimes
# 4       Male  22.000000  1.780000            no   no   2.0  1.0  Sometimes
# ...      ...        ...       ...           ...  ...   ...  ...        ...
# 2106  Female  20.976842  1.710730           yes  yes   3.0  3.0  Sometimes
# 2107  Female  21.982942  1.748584           yes  yes   3.0  3.0  Sometimes
# 2108  Female  22.524036  1.752206           yes  yes   3.0  3.0  Sometimes
# 2109  Female  24.361936  1.739450           yes  yes   3.0  3.0  Sometimes
# 2110  Female  23.664709  1.738836           yes  yes   3.0  3.0  Sometimes
#
#           CH2O  SCC       FAF       TUE        CALC                 MTRANS
# 0     2.000000   no  0.000000  1.000000          no  Public_Transportation
# 1     3.000000  yes  3.000000  0.000000   Sometimes  Public_Transportation
# 2     2.000000   no  2.000000  1.000000  Frequently  Public_Transportation
# 3     2.000000   no  2.000000  0.000000  Frequently                Walking
# 4     2.000000   no  0.000000  0.000000   Sometimes  Public_Transportation
# ...        ...  ...       ...       ...         ...                    ...
# 2106  1.728139   no  1.676269  0.906247   Sometimes  Public_Transportation
# 2107  2.005130   no  1.341390  0.599270   Sometimes  Public_Transportation
# 2108  2.054193   no  1.414209  0.646288   Sometimes  Public_Transportation
# 2109  2.852339   no  1.139107  0.586035   Sometimes  Public_Transportation
# 2110  2.863513   no  1.026452  0.714137   Sometimes  Public_Transportation
#
# [2111 rows x 14 columns]

# %%
Y
# Out:
#                NObeyesdad
# 0           Normal_Weight
# 1           Normal_Weight
# 2           Normal_Weight
# 3      Overweight_Level_I
# 4     Overweight_Level_II
# ...                   ...
# 2106     Obesity_Type_III
# 2107     Obesity_Type_III
# 2108     Obesity_Type_III
# 2109     Obesity_Type_III
# 2110     Obesity_Type_III
#
# [2111 rows x 1 columns]

# %%
lEncoder = LabelEncoder()
columns_to_encode = [0,3,4,7,9,12,13,14]
encoded = dataset.iloc[:, columns_to_encode].apply(lambda col: lEncoder.fit_transform(col))
# Assign the transformed values back to the original DataFrame
dataset.iloc[:, columns_to_encode] = encoded

# %%
dataset
# Out:
#       Gender        Age    Height  familyhistory  FAVC  FCVC  NCP  CAEC  \
# 0          0  21.000000  1.620000              1     0   2.0  3.0     2
# 1          0  21.000000  1.520000              1     0   3.0  3.0     2
# 2          1  23.000000  1.800000              1     0   2.0  3.0     2
# 3          1  27.000000  1.800000              0     0   3.0  3.0     2
# 4          1  22.000000  1.780000              0     0   2.0  1.0     2
# ...      ...        ...       ...            ...   ...   ...  ...   ...
# 2106       0  20.976842  1.710730              1     1   3.0  3.0     2
# 2107       0  21.982942  1.748584              1     1   3.0  3.0     2
# 2108       0  22.524036  1.752206              1     1   3.0  3.0     2
# 2109       0  24.361936  1.739450              1     1   3.0  3.0     2
# 2110       0  23.664709  1.738836              1     1   3.0  3.0     2
#
#           CH2O  SCC       FAF       TUE  CALC  MTRANS  NObeyesdad
# 0     2.000000    0  0.000000  1.000000     3       3           1
# 1     3.000000    1  3.000000  0.000000     2       3           1
# 2     2.000000    0  2.000000  1.000000     1       3           1
# 3     2.000000    0  2.000000  0.000000     1       4           5
# 4     2.000000    0  0.000000  0.000000     2       3           6
# ...        ...  ...       ...       ...   ...     ...         ...
# 2106  1.728139    0  1.676269  0.906247     2       3           4
# 2107  2.005130    0  1.341390  0.599270     2       3           4
# 2108  2.054193    0  1.414209  0.646288     2       3           4
# 2109  2.852339    0  1.139107  0.586035     2       3           4
# 2110  2.863513    0  1.026452  0.714137     2       3           4
#
# [2111 rows x 15 columns]

# %%
#Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
normalizedData = scaler.fit_transform(dataset)
cols = [['Gender', 'Age', 'Height','familyhistory',
       'FAVC', 'FCVC', 'NCP', 'CAEC', 'CH2O', 'SCC', 'FAF', 'TUE',
       'CALC', 'MTRANS', 'NObeyesdad']]
normalizedData = pd.DataFrame(normalizedData, columns=cols)
print(normalizedData.head())
# Out:
#   Gender       Age    Height familyhistory FAVC FCVC       NCP      CAEC CH2O  \
# 0    0.0  0.148936  0.320755           1.0  0.0  0.5  0.666667  0.666667  0.5
# 1    0.0  0.148936  0.132075           1.0  0.0  1.0  0.666667  0.666667  1.0
# 2    1.0  0.191489  0.660377           1.0  0.0  0.5  0.666667  0.666667  0.5
# 3    1.0  0.276596  0.660377           0.0  0.0  1.0  0.666667  0.666667  0.5
# 4    1.0  0.170213  0.622642           0.0  0.0  0.5  0.000000  0.666667  0.5
#
#    SCC       FAF  TUE      CALC MTRANS NObeyesdad
# 0  0.0  0.000000  0.5  1.000000   0.75   0.166667
# 1  1.0  1.000000  0.0  0.666667   0.75   0.166667
# 2  0.0  0.666667  0.5  0.333333   0.75   0.166667
# 3  0.0  0.666667  0.0  0.333333   1.00   0.833333
# 4  0.0  0.000000  0.0  0.666667   0.75   1.000000

# %%
dataset.corr()
#Correlation heatmap
plt.figure(figsize=(15,10))
sns.heatmap(dataset.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#Store the feature and target variable
X = normalizedData.iloc[:, :-1]
X = dataset.iloc[:, :-1]
y = Y

print(dataset.shape)
print(X.shape)
print(y.shape)

#Partition the data into training and test sets (70/30)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=42)
# Out:
# (2111, 15)
# (2111, 14)
# (2111, 1)

# %%
print(X_train.columns)
print(y_train.columns)
# X_train.columns = ['_'.join(map(str, col)).replace(' ', '_') for col in X_train.columns]

# Check the updated column names
# print(X_train.columns)
# Out:
# Index(['G_e_n_d_e_r', 'A_g_e', 'H_e_i_g_h_t', 'f_a_m_i_l_y_h_i_s_t_o_r_y',
#        'F_A_V_C', 'F_C_V_C', 'N_C_P', 'C_A_E_C', 'C_H_2_O', 'S_C_C', 'F_A_F',
#        'T_U_E', 'C_A_L_C', 'M_T_R_A_N_S'],
#       dtype='object')
# Index(['NObeyesdad'], dtype='object')
# Index(['G_e_n_d_e_r', 'A_g_e', 'H_e_i_g_h_t', 'f_a_m_i_l_y_h_i_s_t_o_r_y',
#        'F_A_V_C', 'F_C_V_C', 'N_C_P', 'C_A_E_C', 'C_H_2_O', 'S_C_C', 'F_A_F',
#        'T_U_E', 'C_A_L_C', 'M_T_R_A_N_S'],
#       dtype='object')

# %%
# Compute the baseline classification accuracy for X_train
# !pip install lightgbm
import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf.fit(X_train, y_train)
# Out:
# Requirement already satisfied: lightgbm in c:\users\chris\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: numpy in c:\users\chris\anaconda3\lib\site-packages (from lightgbm) (1.19.2)
# Requirement already satisfied: scipy in c:\users\chris\anaconda3\lib\site-packages (from lightgbm) (1.5.2)
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1805
# [LightGBM] [Info] Number of data points in the train set: 1477, number of used features: 14
# [LightGBM] [Info] Start training from score -2.072022
# [LightGBM] [Info] Start training from score -2.029910
# [LightGBM] [Info] Start training from score -1.780315
# [LightGBM] [Info] Start training from score -1.955434
# [LightGBM] [Info] Start training from score -1.877233
# [LightGBM] [Info] Start training from score -1.989501
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier()

# %%
y_pred=clf.predict(X_test)
# view accuracy
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# LightGBM Model accuracy score: 0.8738

# %%
y_pred_train = clf.predict(X_train)
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 1.0000

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[79  6  0  0  0  1  0]
#  [ 3 76  5  0  0  3  6]
#  [ 0  9 87  3  0  0  3]
#  [ 0  3  1 84  0  0  0]
#  [ 0  1  0  0 97  0  0]
#  [ 1 11  3  1  0 70  2]
#  [ 1  7  3  3  0  4 61]]
#
# True Positives(TP) =  79
#
# True Negatives(TN) =  76
#
# False Positives(FP) =  6
#
# False Negatives(FN) =  3

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.94      0.92      0.93        86
#       Normal_Weight       0.67      0.82      0.74        93
#      Obesity_Type_I       0.88      0.85      0.87       102
#     Obesity_Type_II       0.92      0.95      0.94        88
#    Obesity_Type_III       1.00      0.99      0.99        98
#  Overweight_Level_I       0.90      0.80      0.84        88
# Overweight_Level_II       0.85      0.77      0.81        79
#
#            accuracy                           0.87       634
#           macro avg       0.88      0.87      0.87       634
#        weighted avg       0.88      0.87      0.88       634

# %%
feat_importances = pd.Series(clf.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh', )
# Out:
# <AxesSubplot:>
